# %%
#Gohel Sanjana D.
#216270307093
#Write a NumPy program to implement following operation to split an array of 14 elements into 3 arrays, each with 2, 4, and 8 elements in the original order

import numpy as np

# Create an array with 14 elements
original_array = np.arange(14)

# Split the array into three parts
split_arrays = np.split(original_array, [2,6])

 # Print the split arrays
print(split_arrays)

# %%
#Gohel Sanjana D.
#216270307093
#Write a NumPy program to stack arrays horizontally (column wise)

import numpy as np

print("\n ORIGINAL_ARRAY:")
x = np.arange(9).reshape(3,3)
y= x*3
print("ARRAY 1")
print(x)
print("ARRAY 2")
print(y)
new_array = np.hstack((x,y))
print("stack arrays horizontally ")
print(new_array)
